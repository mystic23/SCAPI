# %% [markdown]
# <a href="https://colab.research.google.com/github/mystic23/SCAPI/blob/main/Taller4_Busqueda_de_Raices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def biseccion(f, ak, bk, tol):
  print('\nMÉTODO DE BISECCIÓN\n')
  print('k\t ak\t bk\t ck\tEa\n')
  Ea=abs(bk-ak)
  k=0
  while Ea>=tol:
    ck=(ak+bk)/2
    print(k,"\t",ak,"\t",bk,"\t\t",ck,"\t",Ea)
    if f(ck)==0:
      print("El valor de la raíz es = ", ck)
      return ck
    else:
      if f(ak)*f(ck)>0:
        ak=ck
      else:
        bk=ck
    Ea=abs(bk-ak)
    k+=1
  print(ck)
  return ck

# %%
def newton(f, df, xk, tol, maxiter):
  print('\nMÉTODO DE NEWTON\n')
  for k in range(maxiter):
    xk1 = xk - f(xk)/df(xk)
    Ea=abs(xk1 - xk)
    print(k,"\t\t",xk,"\t\t",Ea)
    if Ea<tol:
      print("El valor de la raiz es =", xk1)
      return xk1#[xk1,k]
    xk=xk1
  return [None]

# %%
def regula_falsi(f, ak, bk, tol):
    print('\nMÉTODO DE Regula Falsi\n')
    print('k\t ak\t bk\t ck\tEa\n')
    Ea = abs(bk - ak)
    k = 0
    c_ant = 0
    while Ea >= tol:
        ck = bk - (f(bk) * (bk - ak)) / (f(bk) - f(ak))
        Ea = abs(ck - c_ant)
        print(k, "\t", ak, "\t", bk, "\t\t", ck, "\t", Ea)
        if f(ck) == 0:
            return ck
        else:
            if f(ak) * f(ck) > 0:
                ak = ck
            else:
                bk = ck
        k += 1
        c_ant = ck
    print("El valor de la raíz es =", ck)
    return ck

# %%
def Secante(f, xk, xk__1, tol, maxiter):
  print('\nMÉTODO DE LA SECANTE\n')
  for k in range(maxiter):
    xk_1 = xk-((f(xk)*(xk-xk__1))/(f(xk)-f(xk__1)))
    Ea=abs(xk_1 - xk)
    print(k,"\t\t",xk,"\t\t",Ea)
    if Ea<tol:
      print("El valor de la raíz es = ", xk_1)
      return xk_1
    xk__1=xk
    xk=xk_1
  return [None]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = sp.ln(sp.Abs(x-1)) + sp.cos(x-1)
df = f.diff(x)
d2f = df.diff(x)
I=f.integrate(x)
f=sp. lambdify(x, f)
df=sp. lambdify(x, df)
ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = Secante(f, 1.3, 2, 10**-5, 10)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE LA SECANTE
#
# 0 		 1.3 		 0.22060704849829627
# 1 		 1.5206070484982963 		 0.10223924766962744
# 2 		 1.4183678008286689 		 0.02512052864485259
# 3 		 1.3932472721838163 		 0.004659833525981982
# 4 		 1.3979071057097983 		 0.00015741509598221626
# 5 		 1.397749690613816 		 1.2149831694063806e-06
# El valor de la raíz es =  1.3977484756306466

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = sp.exp(-x) - sp.ln(sp.Abs(x))
df = f.diff(x)
d2f = df.diff(x)
I=f.integrate(x)
f=sp. lambdify(x, f)
df=sp. lambdify(x, df)
ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = Secante(f, 1, 2, 10**-5, 10)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE LA SECANTE
#
# 0 		 1 		 0.3974104821696123
# 1 		 1.3974104821696123 		 0.07627996910878498
# 2 		 1.3211305130608273 		 0.011738958037359248
# 3 		 1.309391555023468 		 0.00040993764699193136
# 4 		 1.30980149267046 		 1.906545258112402e-06
# El valor de la raíz es =  1.3097995861252019

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = (x-2)**2 - sp.ln(sp.Abs(x))
df = f.diff(x)
d2f = df.diff(x)
I=f.integrate(x)
f=sp.lambdify(x, f)
df=sp.lambdify(x, df)
ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = Secante(f, 1, 2, 10**-5, 10)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE LA SECANTE
#
# 0 		 1 		 0.5906161091496411
# 1 		 1.5906161091496411 		 0.135078780781825
# 2 		 1.4555373283678161 		 0.049002616081645245
# 3 		 1.4065347122861709 		 0.006027915578332488
# 4 		 1.4125626278645034 		 0.00017079115920370924
# 5 		 1.4123918367052997 		 6.64757104917868e-07
# El valor de la raíz es =  1.4123911719481947

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt


x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = sp.parse_expr(str("ln(abs(x-1))+cos(x-1)"))
df = sp.parse_expr(str("(1/(x-1))-sin(x-1)"))

f= sp.lambdify(x, f)
df= sp.lambdify(x, df)

ejex = np.linspace(-10, 10, 1000)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = newton(f, df, 1.3, 10**-5, maxiter=100)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE NEWTON
#
# 0 		 1.3 		 0.0818471396470386
# 1 		 1.3818471396470386 		 0.015473593292103072
# 2 		 1.3973207329391417 		 0.00042743153447966087
# 3 		 1.3977481644736214 		 3.114849604912706e-07
# El valor de la raiz es = 1.3977484759585819

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt


x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = sp.parse_expr(str("x**2-2*x*exp(-x)+exp(-2*x)"))
df = sp.diff(f, x)
d2f = df.diff(x)
I=f.integrate(x)

f= sp.lambdify(x, f)
df= sp.lambdify(x, df)

ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = newton(f, df, 0, 10**-5, maxiter=100)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE NEWTON
#
# 0 		 0 		 0.25
# 1 		 0.25 		 0.1486396869463762
# 2 		 0.3986396869463762 		 0.08155442847745054
# 3 		 0.48019411542382673 		 0.042772692029426684
# 4 		 0.5229668074532534 		 0.02190931326654133
# 5 		 0.5448761207197947 		 0.011088421876088606
# 6 		 0.5559645425958833 		 0.005578029409248564
# 7 		 0.5615425720051319 		 0.002797516367080255
# 8 		 0.5643400883722122 		 0.0014008894717211229
# 9 		 0.5657409778439333 		 0.0007009782914157991
# 10 		 0.5664419561353491 		 0.0003506226262652845
# 11 		 0.5667925787616144 		 0.00017534469471691683
# 12 		 0.5669679234563313 		 8.768069421682956e-05
# 13 		 0.5670556041505481 		 4.384243383714903e-05
# 14 		 0.5670994465843853 		 2.1921738942110025e-05
# 15 		 0.5671213683233274 		 1.096099925224081e-05
# 16 		 0.5671323293225796 		 5.480532673352023e-06
# El valor de la raiz es = 0.567137809855253

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt


x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = x**4 - 2*x**3 - 4*x**2 + 4*x + 4
df = sp.diff(f, x)
d2f = df.diff(x)
I=f.integrate(x)

f= sp.lambdify(x, f)
df= sp.lambdify(x, df)

ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = newton(f, df, -2, 10**-5, maxiter=100)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE NEWTON
#
# 0 		 -2 		 0.33333333333333326
# 1 		 -1.6666666666666667 		 0.17911479944674968
# 2 		 -1.487551867219917 		 0.06434728567234083
# 3 		 -1.4232045815475762 		 0.008829083078485178
# 4 		 -1.414375498469091 		 0.00016188208660827819
# 5 		 -1.4142136163824828 		 5.400938163369062e-08
# El valor de la raiz es = -1.4142135623731011

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = sp.ln(sp.Abs(x-1)) + sp.cos(x-1)
df = f.diff(x)
d2f = df.diff(x)
I=f.integrate(x)
f=sp. lambdify(x, f)
df=sp. lambdify(x, df)
ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = regula_falsi(f, 1.3, 2, 10**-5)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE Regula Falsi
#
# k	 ak	 bk	 ck	Ea
#
# 0 	 1.3 	 2 		 1.5206070484982963 	 1.5206070484982963
# 1 	 1.3 	 1.5206070484982963 		 1.4183678008286689 	 0.10223924766962744
# 2 	 1.3 	 1.4183678008286689 		 1.4011375031406332 	 0.017230297688035634
# 3 	 1.3 	 1.4011375031406332 		 1.3983040924834074 	 0.0028334106572258655
# 4 	 1.3 	 1.3983040924834074 		 1.3978395317140617 	 0.0004645607693456455
# 5 	 1.3 	 1.3978395317140617 		 1.3977633974589243 	 7.613425513741667e-05
# 6 	 1.3 	 1.3977633974589243 		 1.3977509211516925 	 1.247630723177906e-05
# 7 	 1.3 	 1.3977509211516925 		 1.3977488766529436 	 2.0444987489653954e-06
# El valor de la raíz es = 1.3977488766529436

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = sp.exp(-x) - sp.ln(sp.Abs(x))
df = f.diff(x)
d2f = df.diff(x)
I=f.integrate(x)
f=sp. lambdify(x, f)
df=sp. lambdify(x, df)
ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = regula_falsi(f, 1, 2, 10**-5)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE Regula Falsi
#
# k	 ak	 bk	 ck	Ea
#
# 0 	 1 	 2 		 1.3974104821696125 	 1.3974104821696125
# 1 	 1 	 1.3974104821696125 		 1.3211305130608273 	 0.0762799691087852
# 2 	 1 	 1.3211305130608273 		 1.3112695561467471 	 0.009860956914080177
# 3 	 1 	 1.3112695561467471 		 1.30999036556506 	 0.0012791905816871285
# 4 	 1 	 1.30999036556506 		 1.3098243474551408 	 0.00016601810991923038
# 5 	 1 	 1.3098243474551408 		 1.3098027996863728 	 2.154776876794884e-05
# 6 	 1 	 1.3098027996863728 		 1.309800002943072 	 2.796743300725879e-06
# El valor de la raíz es = 1.309800002943072

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = (x - 2)**2 - sp.ln(sp.Abs(x))
df = f.diff(x)
d2f = df.diff(x)
I=f.integrate(x)
f=sp. lambdify(x, f)
df=sp. lambdify(x, df)
ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = regula_falsi(f, 1 , 2, 10**-5)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE Regula Falsi
#
# k	 ak	 bk	 ck	Ea
#
# 0 	 1 	 2 		 1.5906161091496414 	 1.5906161091496414
# 1 	 1 	 1.5906161091496414 		 1.4555373283678164 	 0.135078780781825
# 2 	 1 	 1.4555373283678164 		 1.42220996149836 	 0.033327366869456254
# 3 	 1 	 1.42220996149836 		 1.414593609829872 	 0.007616351668488175
# 4 	 1 	 1.414593609829872 		 1.4128835918808942 	 0.0017100179489777378
# 5 	 1 	 1.4128835918808942 		 1.4125011867969124 	 0.00038240508398179607
# 6 	 1 	 1.4125011867969124 		 1.4124157471489938 	 8.543964791862813e-05
# 7 	 1 	 1.4124157471489938 		 1.4123966614212518 	 1.9085727742007563e-05
# 8 	 1 	 1.4123966614212518 		 1.4123923981921531 	 4.263229098633303e-06
# El valor de la raíz es = 1.4123923981921531

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x= sp.symbols('x')
# f= sp.parse_expr(input("Por favor, digita un vector de funciones f(x")) # x*exp(-x**2/10)
f = sp.parse_expr(str("x**2-2*x*exp(-x)+exp(-2*x)"))
df = f.diff(x)
d2f = df.diff(x)
I=f.integrate(x)
f=sp. lambdify(x, f)
df=sp. lambdify(x, df)
ejex = np.linspace(-10, 10, 1000)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.grid()

# %%
raiz1 = regula_falsi(f, 0 , 1, 0.001)
plt.plot(ejex, f(ejex) , raiz1, f(raiz1), 'om')
plt.grid()
plt.legend('abcd')
plt.show()
# Out:
# MÉTODO DE Regula Falsi
#
# k	 ak	 bk	 ck	Ea
#
# 0 	 0 	 1 		 1.6654908326196636 	 1.6654908326196636
# 1 	 1.6654908326196636 	 1 		 0.8506232908396686 	 0.814867541779995
# 2 	 0.8506232908396686 	 1 		 0.7289961354111876 	 0.12162715542848102
# 3 	 0.7289961354111876 	 1 		 0.6803468678237653 	 0.048649267587422274
# 4 	 0.6803468678237653 	 1 		 0.6541718154703213 	 0.026175052353443973
# 5 	 0.6541718154703213 	 1 		 0.6378236794581846 	 0.016348136012136694
# 6 	 0.6378236794581846 	 1 		 0.6266442857013945 	 0.011179393756790112
# 7 	 0.6266442857013945 	 1 		 0.6185174210777147 	 0.008126864623679841
# 8 	 0.6185174210777147 	 1 		 0.6123432381623218 	 0.006174182915392845
# 9 	 0.6123432381623218 	 1 		 0.6074935514753492 	 0.00484968668697261
# 10 	 0.6074935514753492 	 1 		 0.6035835045965874 	 0.003910046878761841
# 11 	 0.6035835045965874 	 1 		 0.6003641635411017 	 0.003219341055485714
# 12 	 0.6003641635411017 	 1 		 0.5976673834580641 	 0.002696780083037531
# 13 	 0.5976673834580641 	 1 		 0.5953754961672101 	 0.0022918872908540555
# 14 	 0.5953754961672101 	 1 		 0.593403692378263 	 0.001971803788947124
# 15 	 0.593403692378263 	 1 		 0.5916893009998778 	 0.0017143913783851383
# 16 	 0.5916893009998778 	 1 		 0.5901850084871137 	 0.0015042925127640716
# 17 	 0.5901850084871137 	 1 		 0.588854426424878 	 0.0013305820622357967
# 18 	 0.588854426424878 	 1 		 0.5876691103883522 	 0.0011853160365257187
# 19 	 0.5876691103883522 	 1 		 0.5866065044067545 	 0.0010626059815976863
# 20 	 0.5866065044067545 	 1 		 0.5856484922522989 	 0.0009580121544556786
# El valor de la raíz es = 0.5856484922522989
