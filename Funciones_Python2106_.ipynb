# %% [markdown]
# <a href="https://colab.research.google.com/github/mystic23/SCAPI/blob/main/Funciones_Python2106_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio No 1. Leer y graficar cualquier función

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
#np.linspace()    np.arange()
#3*x**2+.1*x-.5

x = sp.symbols('x')
f = sp.parse_expr(input("porfavor, digita la funcion f(x) = ")) ## leer lo que es una función x*exp(-x**2/10)
print(sp.lambdify(x,f)(np.linspace(-1,3,5)))
func= sp.lambdify(x,f)
ejex = np.linspace(-1,3) #sino le digo cuentos me grafica 50
ejey = func(ejex)

plt.plot(ejex,ejey)
plt.xlabel('Eje x')
plt.ylabel('Eje y')

plt.title('Grafico de f(x)')
plt.show()
# Out:
# porfavor, digita la funcion f(x) = 3*x**2+.1*x-.5
# [ 2.4 -0.5  2.6 11.7 26.8]

# %% [markdown]
# Ejercicio No 2. Leer una función y encontrar la función de su primera derivada: f

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
#np.linspace()    np.arange()
#3*x**2+.1*x-.5

x = sp.symbols('x')
f = sp.parse_expr(input("porfavor, digita un vector de funciones f(x) = "))
print(sp.lambdify(x,f)(np.linspace(-1,3,5)))
func= sp.lambdify(x,f)
ejex = np.linspace(-1,3) #sino le digo cuentos me grafica 50
ejey = func(ejex)

plt.plot(ejex,np.transpose(ejey))
plt.xlabel('Eje x')
plt.ylabel('Eje y')

plt.title('Grafico de f(x)')
plt.show()
#insertar los valores entre corchetes
# Out:
# porfavor, digita un vector de funciones f(x) = [cos(x), exp(x)+x, x**2+2]
# [array([ 0.54030231,  1.        ,  0.54030231, -0.41614684, -0.9899925 ]), array([-0.63212056,  1.        ,  3.71828183,  9.3890561 , 23.08553692]), array([ 3.,  2.,  3.,  6., 11.])]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x = sp.symbols('x')
f = sp.parse_expr(input("porfavor, digita un vector de funciones f(x) = "))
df = f.diff(x)
ejex = np.linspace(-1,1)
ejey = sp.lambdify(x,[f,df])(ejex)
plt.plot(ejex,np.transpose(ejey))
plt.show()
# Out:
# porfavor, digita un vector de funciones f(x) = 3*x**2+.1*x-.5

# %%
#segunda derivada
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x = sp.symbols('x')
f = sp.parse_expr(input("porfavor, digita un vector de funciones f(x) = "))
df = f.diff(x)
d2f = df.diff(x)
ejex = np.linspace(-1,1)
ejey = sp.lambdify(x,[f,df,d2f])(ejex)
plt.plot(ejex, np.transpose(ejey))
##tiene que ser una funcion de grado **3
plt.show()
# Out:
# porfavor, digita un vector de funciones f(x) =  x**3+2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

x = sp.symbols('x')
f = sp.parse_expr(input("porfavor, digita la funcion f(x) = "))

df = f.diff(x)

ejex = np.linspace(-10, 10, 100)

ejey = sp.lambdify(x, f)(ejex)
df_ejex = sp.lambdify(x, df)(ejex)

x0 = float(input("Ingrese el valor de x0: "))
y0 = sp.lambdify(x, f)(x0)

#  pendiente de la recta tangente
m = float(sp.lambdify(x, df)(x0))


tangente_ejey = y0 + m * (ejex - x0)

# Graficar la función y la recta tangente
plt.plot(ejex, ejey, label='f(x)')
plt.plot(ejex, tangente_ejey, label='Recta tangente')
plt.scatter(x0, y0, color='red', label='Punto (x0, f(x0))')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
#f(x) = x**2 + 2*x + 1
#x0 = -1
# Out:
# porfavor, digita la funcion f(x) = x**2 + 2*x + 1
# Ingrese el valor de x0: -1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy.polys.polyroots import roots
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

x = sp.symbols('x')
f = sp.parse_expr(input("porfavor, digita la funcion f(x) = "))
Pn = sp.Poly(f)
coef_Pn = Pn.all_coeffs()
raices = (np.roots(coef_Pn)).real
ejex= np.linspace(-5,6) #(-5,6)
ejey=np.polyval(coef_Pn,ejex)
plt.plot(ejex,ejey,raices,np.zeros(len(raices)),'om')
#f(x)=(x+1)*(x-.5)**2*(x+7)**3
#f(x) = (x-1)*(x+3)**3*(x-5)**2
#f(x) = (x-1)*(x+3)**3*(x-5)**2  #cuando la multiplicidad es **2 es una recta tangente al eje x
plt.show()
# Out:
# porfavor, digita la funcion f(x) = (x-1)*(x+3)**3*(x-5)**2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 22 de junio del 2022

# %%
#GRAFICACION COLECTIVA

import numpy as np, sympy as sp,matplotlib.pyplot as plt
#
x=sp.symbols('x')
f=sp.parse_expr(input('Por favor, digita un vector de funciones f(x) = '))# x*exp(-x**2/10)
df=f.diff(x)
d2f=df.diff(x)
I=f.integrate(x)
f=sp.lambdify(x, [f, df, d2f])
ejex = np.linspace(-10, 10)
ejey = f(ejex)
plt.plot(ejex, np.transpose(ejey))
plt.xlabel('ejex')
plt.ylabel('ejey')
plt.grid()
# Out:
# Por favor, digita un vector de funciones f(x) = x*exp(-x**2/10)

# %%
#GRAFICACION INDIVIDUAL
import numpy as np, sympy as sp,matplotlib.pyplot as plt
#
x = sp.symbols('x')
f=sp.parse_expr(input('Por favor, digita un vector de funciones f(x) = '))# x*exp(-x**2/10)
df=f.diff(x)
d2f=df.diff(x)
I=f.integrate(x)
#f=sp.lambdify(x, [f, df, d2f, I, -I])#-I es el espejo de la integral, si la cambias el signo es la misma imagen y usa el eje x como espejo
f=sp.lambdify(x, f)
df=sp.lambdify(x, df)
d2f=sp.lambdify(x, d2f)
I=sp.lambdify(x, I)

#Aqui las estoy ubicando individualmente
ejex = np.linspace(-10, 10)
# ejey = f(ejex),df(ejex),d2f(ejex),I(ejex)
plt.plot(ejex, df(ejex))
plt.xlabel('ejex')
plt.ylabel('ejey')
plt.grid()

plt.legend('abcd') #brinda asignaciones especificas a los colores

plt.show()


#x*exp(-x**2/10)
# Out:
# Por favor, digita un vector de funciones f(x) = x*exp(-x**2/10)

# %% [markdown]
# ¿Qué es una raiz?, es un punto donde una parte de la funcion corta el ejex
# R = (x)  f(x) = 0
#
# Metodos para buscar raices: abiertos o cerrados
# Bolsano: la raiz debe debe ser continua y debe haber un cambio de signo
#
# ejemplo del anterior:
#
#     de izquierda derecha es -2.5 a 0.0

# %%
#GRAFICACION INDIVIDUAL CON BOLSANO DEL COMENTARIO ANTERIOR
#BIcepcion
#encontrar el punto medio entre ambos valores, linea naranja y verde
#1. conocer la funcion
#2. grficar y escoger un itnervalo que se aplique bolsado, continua, derivable y cambio de signo

import numpy as np, sympy as sp,matplotlib.pyplot as plt
#
x = sp.symbols('x')
f=sp.parse_expr(input('Por favor, digita un vector de funciones f(x) = '))# x*exp(-x**2/10)
df=f.diff(x)
d2f=df.diff(x)
I=f.integrate(x)
#f=sp.lambdify(x, [f, df, d2f, I, -I])#-I es el espejo de la integral, si la cambias el signo es la misma imagen y usa el eje x como espejo
f=sp.lambdify(x, f)
df=sp.lambdify(x, df)
d2f=sp.lambdify(x, d2f)
I=sp.lambdify(x, I)

#Aqui las estoy ubicando individualmente
ejex = np.linspace(-10, 10)
# ejey = f(ejex),df(ejex),d2f(ejex),I(ejex)

#juntos
plt.plot(ejex, df(ejex), [-5,-5],[0, df(-5)],[0,0],[0,df(0)],-2.5,0,'.' ) #hace la recta vertical, los valores de x no pueden cambiar ene ste caso es [x,y]
# plt.plot(ejex, df(ejex), [0,0],[0, df(0)]) #individual

plt.xlabel('ejex')
plt.ylabel('ejey')
plt.grid()

plt.legend('abcd') #brinda asignaciones especificas a los colores

plt.show()


#x*exp(-x**2/10)
# Out:
# Por favor, digita un vector de funciones f(x) = x*exp(-x**2/10)
