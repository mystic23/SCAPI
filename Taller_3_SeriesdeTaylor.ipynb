# %% [markdown]
# <a href="https://colab.research.google.com/github/mystic23/SCAPI/blob/main/Taller_3_SeriesdeTaylor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Solución del taller**

# %% [markdown]
# El algoritmo fue codificado gradias a la siguiente formula ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Documentación generica

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    """
    En este código, la función TaylorPoly() calcula la serie
    de Taylor para la función f(x) = variable f.
    Se utiliza la biblioteca sympy para trabajar con expresiones
    simbólicas. La función toma dos argumentos: a (punto de expansión)
    y n (número de términos en la serie de Taylor). La función imprime
    el valor de la serie de Taylor.

    Args:
        a (int): Punto de expansión de la serie de Taylor.
        n (int): Número de términos en la serie de Taylor.

    Returns:
        None. Imprime el valor de la serie de Taylor.

    """
    x = sp.symbols('x')
    f  =  "AQUI VA LA SERIE QUE QUIERES CALCULAR"
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5) #Aqui el valor de a y n

# %%
import sympy as sp
from math import factorial

def estimar_seno(a: int, error: float) -> float:
    """
    Estima el valor de la función seno en el punto a, agregando términos a la serie de Taylor
    hasta que el error absoluto sea menor que el valor de error.

    Args:
        a (int): Punto de evaluación.
        error (float): Valor máximo del error absoluto permitido.

    Returns:
        float: Valor estimado de la función seno en el punto a.

    """
    x = sp.symbols('x')
    f = sp.cos(x)
    F = f
    T = f.subs(x, a)
    k = 1
    while True:
        dfk = sp.diff(f, x)
        term = dfk.subs(x, a) * ((x - a) ** k) / factorial(k)
        T += term
        k += 1
        if abs(term.subs(x, 1)) < error:
            break
    return T.subs(x, 1).evalf()

# Estimar el valor de f(1) con un error absoluto menor que 10^-3
valor_estimado = estimar_seno(0, 1e-3)

print("El valor estimado de f(1) es:", valor_estimado)

# %% [markdown]
# # Parte 1 - Word

# %% [markdown]
# a. Determine la serie de Taylor para la función f(x)=1/(1+x),en a=0.

# %%
from IPython.display import display, Math
from sympy.parsing.sympy_parser import parse_expr
from sympy import Poly
import sympy as sp

f = parse_expr(input("Digita la f(x) ="))
print(display(Math(sp. latex(f))))

Fx = Poly(f.series().removeO())
Fx.rep
# Out:
# Digita la f(x) =1/(1+x)
# $\displaystyle \frac{1}{x + 1}$
# None
# DMP([-1, 1, -1, 1, -1, 1], ZZ, None)

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  1/(1+x)
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: -x**5 + x**4 - x**3 + x**2 - x + 1

# %% [markdown]
# b. Determine la serie de Taylor para la función f(x)=e^x+1,en a=0. Estimar el valor de f(1) agregando términos a la serie hasta que el error absoluto sea menor que 10^-3.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  sp.exp(x) + 1
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**5/120 + x**4/24 + x**3/6 + x**2/2 + x + 2

# %%
import sympy as sp
from math import factorial

def estimar_seno(a: int, error: float) -> float:
    x = sp.symbols('x')
    f = sp.exp(x) + 1
    F = f
    T = f.subs(x, a)
    k = 1
    while True:
        dfk = sp.diff(f, x)
        term = dfk.subs(x, a) * ((x - a) ** k) / factorial(k)
        T += term
        k += 1
        if abs(term.subs(x, 1)) < error:
            break
    return T.subs(x, 1).evalf()

# Estimar el valor de f(1) con un error absoluto menor que 10^-3
valor_estimado = estimar_seno(0, 1e-3)

print("El valor estimado de f(1) es:", valor_estimado)
# Out:
# El valor estimado de f(1) es: 3.71825396825397

# %% [markdown]
# c. Determine la serie de Taylor para la función f(x)=cos⁡(x),en a=0. Estimar el valor de f(1) agregando términos a la serie hasta que el error absoluto sea menor que 10^-3.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  sp.cos(x)
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**4/24 - x**2/2 + 1

# %%
import sympy as sp
from math import factorial

def estimar_seno(a: int, error: float) -> float:
    x = sp.symbols('x')
    f = sp.cos(x)
    F = f
    T = f.subs(x, a)
    k = 1
    while True:
        dfk = sp.diff(f, x)
        term = dfk.subs(x, a) * ((x - a) ** k) / factorial(k)
        T += term
        k += 1
        if abs(term.subs(x, 1)) < error:
            break
    return T.subs(x, 1).evalf()

# Estimar el valor de f(1) con un error absoluto menor que 10^-3
valor_estimado = estimar_seno(0, 1e-3)

print("El valor estimado de f(1) es:", valor_estimado)
# Out:
# El valor estimado de f(1) es: 1.00000000000000

# %% [markdown]
# d. Determine la serie de Taylor para la función f(x)=sen⁡(x),en a=0. Estimar el valor de f(1) agregando términos a la serie hasta que el error absoluto sea menor que 10^-3.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  sp.sin(x)
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**5/120 - x**3/6 + x

# %%
import sympy as sp
from math import factorial

def estimar_seno(a: int, error: float) -> float:
    x = sp.symbols('x')
    f = sp.sin(x)
    F = f
    T = f.subs(x, a)
    k = 1
    while True:
        dfk = sp.diff(f, x)
        term = dfk.subs(x, a) * ((x - a) ** k) / factorial(k)
        T += term
        k += 1
        if abs(term.subs(x, 1)) < error:
            break
    return T.subs(x, 1).evalf()

# Estimar el valor de f(1) con un error absoluto menor que 10^-3
valor_estimado = estimar_seno(0, 1e-3)

print("El valor estimado de f(1) es:", valor_estimado)
# Out:
# El valor estimado de f(1) es: 1.71825396825397

# %% [markdown]
# e. Determine la serie de Taylor para la función f(x)=x^3+2x+1,en a=0.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  x**3 + 2*x + 1
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**3 + 2*x + 1

# %% [markdown]
# f. Determine la serie de Taylor para la función f(x)=ln⁡(1+x),en a=0.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  sp.ln(1 + x)
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**5/5 - x**4/4 + x**3/3 - x**2/2 + x

# %% [markdown]
# g.Determine la serie de Taylor para la función f(x)=1/(2+3x),en a=0.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  = 1 / (2 + 3*x)
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: -243*x**5/64 + 81*x**4/32 - 27*x**3/16 + 9*x**2/8 - 3*x/4 + 1/2

# %% [markdown]
# # Parte 2 -  Ejercicios Sueltos

# %% [markdown]
# a. Determine la serie de Taylor para la función 𝑓(𝑥)=11+𝑥,𝑒𝑛 𝑎=0.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  11 + x
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x + 11

# %% [markdown]
# b. Determine la serie de Taylor para la función 𝑓(𝑥)=𝑒𝑥+1,𝑒𝑛 𝑎=0. Estimar el valor de f(1) agregando términos a la serie hasta que el error absoluto sea menor que 10^-3.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  sp.exp(x) + 1
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**5/120 + x**4/24 + x**3/6 + x**2/2 + x + 2

# %%
import sympy as sp
from math import factorial

def estimar_seno(a: int, error: float) -> float:
    x = sp.symbols('x')
    f = sp.exp(x) + 1
    F = f
    T = f.subs(x, a)
    k = 1
    while True:
        dfk = sp.diff(f, x)
        term = dfk.subs(x, a) * ((x - a) ** k) / factorial(k)
        T += term
        k += 1
        if abs(term.subs(x, 1)) < error:
            break
    return T.subs(x, 1).evalf()

# Estimar el valor de f(1) con un error absoluto menor que 10^-3
valor_estimado = estimar_seno(0, 1e-3)

print("El valor estimado de f(1) es:", valor_estimado)
# Out:
# El valor estimado de f(1) es: 3.71825396825397

# %% [markdown]
# c. Determine la serie de Taylor para la función 𝑓(𝑥)=cos⁡(𝑥),𝑒𝑛 𝑎=0. Estimar el valor de f(1) agregando términos a la serie hasta que el error absoluto sea menor que 10^-3.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  sp.cos(x)
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**4/24 - x**2/2 + 1

# %%
import sympy as sp
from math import factorial

def estimar_seno(a: int, error: float) -> float:
    x = sp.symbols('x')
    f = sp.cos(x)
    F = f
    T = f.subs(x, a)
    k = 1
    while True:
        dfk = sp.diff(f, x)
        term = dfk.subs(x, a) * ((x - a) ** k) / factorial(k)
        T += term
        k += 1
        if abs(term.subs(x, 1)) < error:
            break
    return T.subs(x, 1).evalf()

# Estimar el valor de f(1) con un error absoluto menor que 10^-3
valor_estimado = estimar_seno(0, 1e-3)

print("El valor estimado de f(1) es:", valor_estimado)
# Out:
# El valor estimado de f(1) es: 1.00000000000000

# %% [markdown]
# d. Determine la serie de Taylor para la función 𝑓(𝑥)=sen⁡(𝑥),𝑒𝑛 𝑎=0. Estimar el valor de f(1) agregando términos a la serie hasta que el error absoluto sea menor que 10^-3.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  sp.sin(x)
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**5/120 - x**3/6 + x

# %%
import sympy as sp
from math import factorial

def estimar_seno(a: int, error: float) -> float:
    x = sp.symbols('x')
    f = sp.sin(x)
    F = f
    T = f.subs(x, a)
    k = 1
    while True:
        dfk = sp.diff(f, x)
        term = dfk.subs(x, a) * ((x - a) ** k) / factorial(k)
        T += term
        k += 1
        if abs(term.subs(x, 1)) < error:
            break
    return T.subs(x, 1).evalf()

# Estimar el valor de f(1) con un error absoluto menor que 10^-3
valor_estimado = estimar_seno(0, 1e-3)

print("El valor estimado de f(1) es:", valor_estimado)
# Out:
# El valor estimado de f(1) es: 1.71825396825397

# %% [markdown]
# e. Determine la serie de Taylor para la función 𝑓(𝑥)=𝑥3+2𝑥+1,𝑒𝑛 𝑎=0.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  = x*3+2*x+1
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: 5*x + 1

# %% [markdown]
# f. Determine la serie de Taylor para la función 𝑓(𝑥)=ln⁡(1+𝑥),𝑒𝑛 𝑎=0.

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  = sp.ln(1 + x)
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: x**5/5 - x**4/4 + x**3/3 - x**2/2 + x

# %% [markdown]
# g. Determine la serie de Taylor para la función 𝑓(𝑥)=12+3𝑥,𝑒𝑛 𝑎=0

# %%
from math import factorial
import sympy as sp
def TaylorPoly(a: int, n: int) -> None:
    x = sp.symbols('x')
    f  =  12+3*x
    F = f
    T = f.subs(x, a)
    for k in range(1, n+1):
        dfk = sp.diff(f, x)
        T = T + dfk.subs(x, a)*((x - a)**(k))/factorial(k)
        f = dfk
    print("Valor de la serie:", sp.expand(T))

TaylorPoly(a=0, n=5)
# Out:
# Valor de la serie: 3*x + 12
