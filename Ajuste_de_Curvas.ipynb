# %% [markdown]
# <a href="https://colab.research.google.com/github/mystic23/SCAPI/blob/main/Ajuste_de_Curvas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #El ajuste racional
#
# $y=\dfrac{D}{x+C}$
#
# Página 305 del libro Guía

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Explicación
#
# $Y = m ⋅ X + b $
#
# Donde:
#
#     Y = Modelo deterministico (para una x dada, Y siempre te dara lo mismo)
#     m = cantidad asociada al numero de X cosas dadas (ejemplo: precio)
#     X = Unidades (ejemplo: unidades vendidas)
#     b = Valor fijo

# %% [markdown]
# **Modelo**
#
# -Original: $Y = m⋅X+b$
#
# Ejemplo: modelo de el peso de las personas al nacer
#
# donde,
#
# y = w de las personas al nacer
# t = tiempo
#
# **MODELO EJEMPLO**
#
# $w = m*t+b$ **-->"el peor"**
#
# t = 0  | w1,w2,w3,w4 ... $w_{n}$ | E(w|t)
#
# t = 1  | w1',0,w3',w4'...$w_{m}$ |
#
#  Nacieron n niños

# %%
#Autor: Profesor Alfonso Mancilla
import numpy as np, matplotlib.pyplot as plt
#1. Datos de entrada y ecuaciones de las curvas que se ajustarán
x=np.array([1,2,3,4,5])
y=np.array([2, 5, 10, 17, 26])
y1calc=lambda x,C,D: D/(x+C); y2calc=lambda x,A,B: 1/(A*x+B)
#2. Transformación. "Linealización de las curvas"
X=np.multiply(x, y); Y=y
#3. Aumentar X con un vector de unos
X=(np.array([np.ones(len(x)), X])).T
# 4. Aplicar mínimos cuadrados para obtener los parámetros de la linealización del modelo
#p, res, rnk, s = lstsq(M, y)
mb,_,_,_=np.linalg.lstsq(X,Y)
#5. Obtención de la pendiente y el intercepto de la recta obtenida por mínimos cuadrados
b=mb[0]; m=mb[1]
# 6. Obtener los parámetros de la curva ajustada, en función de $m$ y $b$, con las ecuaciones de la linealización
C=-1/m; D=C*b
# Modelo2
X=x; Y=1/y
X=(np.array([np.ones(len(x)), x])).T
mb,_,_,_=np.linalg.lstsq(X,Y)
b=mb[0]
m=mb[1]
# Equivalencias Modelo2
A=m
B=b
# 7. Gráficas. Puntos, curvas ajustadas, recta de regresión, polinomiio de interpolación y otras
ejex=np.linspace(min(x),max(x))

fig, ax = plt.subplots()
ax.plot(x,y,'*k');xl=plt.xlim();yl=plt.ylim()
print(plt.xlim(),plt.ylim())
ax.plot(ejex,y1calc(ejex,C,D),'.m',ejex,y2calc(ejex,A,B),'oc');
plt.xlim(xl),plt.ylim(yl)
print(D,C,A,B)
# Out:
# <ipython-input-11-4f02b39ae2b7>:13: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   mb,_,_,_=np.linalg.lstsq(X,Y)
# <ipython-input-11-4f02b39ae2b7>:21: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   mb,_,_,_=np.linalg.lstsq(X,Y)
# (0.8, 5.2) (0.7999999999999998, 27.2)
# -17.71940298507463 -5.476616915422886 -0.10642533936651583 0.498733031674208

# %% [markdown]
# #Ejercicio #2
#
# Datos:
# ![image.png](data:image/png;base64,...)
#
# **Datos de solución**
# ![image.png](data:image/png;base64,...)
#
# **Ajuste de curva: resultado**
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Autor: Profesor Alfonso Mancilla
x = np.array([0, 1, 2, 3, 4])
y = np.array([1.5, 2.5, 3.5, 5.0, 7.5])
#funcion
y_calc = lambda x, C, A: C * np.exp(A * x)

# Aqui linealizamos la curva
X = x
Y = np.log(y)

X = (np.array([np.ones(len(x)), X])).T
mb, _, _, _ = np.linalg.lstsq(X, Y)

b=mb[0]
B=b
C = np.exp(mb[0])
A = mb[1]
print('C=',C,' A=', A, 'B =' , B)
ejex = np.linspace(min(x), max(x))
fig, ax = plt.subplots()
ax.plot(x, y, '*k')
ax.plot(ejex, y_calc(ejex, C, A), '-r')
# #esto sirve para colocarle el titulito al ladito de la curva
equation_name = r'$y = C \cdot e^{Ax}$'
plt.text(2.5, 6, equation_name, fontsize=12)

plt.show()
# Out:
# <ipython-input-47-f3756b76920d>:15: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   mb, _, _, _ = np.linalg.lstsq(X, Y)
# C= 1.579909152874635  A= 0.39120230054281474 B = 0.45736734720518085

# %%
#Autor: Profesor Alfonso Mancilla
import numpy as np, matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=np.array([2, 5, 10, 17, 26])
y2calc=lambda x,A,B: 1/(A*x+B)

X=np.multiply(x, y); Y=y
X=(np.array([np.ones(len(x)), X])).T
#p, res, rnk, s = lstsq(M, y)
mb,_,_,_=np.linalg.lstsq(X,Y)
b=mb[0]; m=mb[1]
C=-1/m; D=C*b

# Modelo2
X=x; Y=1/y
X=(np.array([np.ones(len(x)), x])).T
mb,_,_,_=np.linalg.lstsq(X,Y)
b=mb[0]
m=mb[1]
# Equivalencias Modelo2
A=m
B=b
ejex=np.linspace(min(x),max(x))

fig, ax = plt.subplots()
ax.plot(x,y,'*k');xl=plt.xlim();yl=plt.ylim()
print(plt.xlim(),plt.ylim())
ax.plot(ejex,y2calc(ejex,A,B),'oc');
plt.xlim(xl),plt.ylim(yl)
print(D,C,A,B)
# Out:
# <ipython-input-48-af2ed0d97108>:10: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   mb,_,_,_=np.linalg.lstsq(X,Y)
# <ipython-input-48-af2ed0d97108>:17: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   mb,_,_,_=np.linalg.lstsq(X,Y)
# (0.8, 5.2) (0.7999999999999998, 27.2)
# -17.71940298507463 -5.476616915422886 -0.10642533936651583 0.498733031674208

# %% [markdown]
# #Codigos Graficas completos:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de entrada
x = np.array([0, 1, 2, 3, 4])
y = np.array([1.5, 2.5, 3.5, 5.0, 7.5])

# Función y = A/x
y_calc = lambda x, A: -3 / x

# Linealización de la curva
X = x
Y = -3 / y

X = (np.array([np.ones(len(x)), X])).T
mb, _, _, _ = np.linalg.lstsq(X, Y)

A = mb[1]
print('A =', A)

# Gráfico
ejex = np.linspace(min(x), max(x))
fig, ax = plt.subplots()
ax.plot(x, y, '*k')
ax.plot(ejex, y_calc(ejex, A), '-r')

# Título de la curva
equation_name = r'$y = \frac{A}{x}$'
plt.text(2.5, 6, equation_name, fontsize=12)

plt.show()
# Out:
# <ipython-input-9-6a28c1aa6fc2>:16: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   mb, _, _, _ = np.linalg.lstsq(X, Y)
# <ipython-input-9-6a28c1aa6fc2>:9: RuntimeWarning: divide by zero encountered in true_divide
#   y_calc = lambda x, A: -3 / x
# A = 0.38

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros
A = -3
B = 4


x = np.linspace(0.1, 5, 100)
y = A / x

fig, ax = plt.subplots()
ax.plot(x, y, '-r')
equation_name = r'$y = \frac{A}{x}$'
plt.text(2.5, -10, equation_name, fontsize=12)

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros
A = -1/2
B = 1
x = np.linspace(0.1, 100, 100)
y = A * np.log(x) + B

y_calc = lambda x, A, B: x/(A +B*x)
fig, ax = plt.subplots()
ax.plot(x, y, '-k')

# Título de la curva
equation_name = r'$y = x/(A +B*x)$'
plt.text(2.5, 2, equation_name, fontsize=12)

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros
A = 2
B = 3/2

x = np.linspace(0.1, 5, 100)
y = A * np.log(x) + B

y_calc = lambda x, A, B: A * np.log(x) + B
fig, ax = plt.subplots()
ax.plot(x, y, '-k')

# Título de la curva
equation_name = r'$y = A \cdot \ln(x) + B$'
plt.text(2.5, 2, equation_name, fontsize=12)

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros
A = -2
B = 2

x = np.linspace(0.1, 100, 100)
y = A * np.log(x) + B

y_calc = lambda x, A, B: A * np.log(x) + B
fig, ax = plt.subplots()
ax.plot(x, y, '-k')

# Título de la curva
equation_name = r'$y = A \cdot \ln(x) + B$'
plt.text(2.5, 2, equation_name, fontsize=12)

plt.show()
